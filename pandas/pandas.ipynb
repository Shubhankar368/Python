# %%
import pandas as pd

# %%
import numpy as np

# %%
dict1={    "Name":['shubhankar','yogesh','babita','thugesh'],
           "Marks":[89,56,78,34],
           "City":["Delhi","rampur","kolapur","ahemdabad"]
      }

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#          Name  Marks       City
# 0  shubhankar     89      Delhi
# 1      yogesh     56     rampur
# 2      babita     78    kolapur
# 3     thugesh     34  ahemdabad

# %%
print(df)
# Out:
#          Name  Marks       City
# 0  shubhankar     89      Delhi
# 1      yogesh     56     rampur
# 2      babita     78    kolapur
# 3     thugesh     34  ahemdabad

# %%
df.to_csv('friends.csv')

# %%
df.to_csv('friends_index=false.csv',index=False)

# %%
df.head(2)
# Out:
#          Name  Marks    City
# 0  shubhankar     89   Delhi
# 1      yogesh     56  rampur

# %%
df.tail(2)
# Out:
#       Name  Marks       City
# 2   babita     78    kolapur
# 3  thugesh     34  ahemdabad

# %%
df.describe()
# Out:
#            Marks
# count   4.000000
# mean   64.250000
# std    24.390914
# min    34.000000
# 25%    50.500000
# 50%    67.000000
# 75%    80.750000
# max    89.000000

# %%
train=pd.read_csv("train.csv")

# %%
train
# Out:
#    Unnamed: 0    Train name  Train no     City  Unnamed: 4  Unnamed: 5  \
# 0           0      shatabdi    103044  lucknow         NaN         NaN
# 1           1      rajdhani    134345   mumbai         NaN         NaN
# 2           2  Vande bharat    553567  varansi         NaN         NaN
# 3           3         Tejas    535646    delhi         NaN         NaN
#
#    Unnamed: 6
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN

# %%
print(train)
# Out:
#    Unnamed: 0    Train name  Train no     City  Unnamed: 4  Unnamed: 5  \
# 0           0      shatabdi    103044  lucknow         NaN         NaN
# 1           1      rajdhani    134345   mumbai         NaN         NaN
# 2           2  Vande bharat    553567  varansi         NaN         NaN
# 3           3         Tejas    535646    delhi         NaN         NaN
#
#    Unnamed: 6
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN

# %%
train
# Out:
#    Unnamed: 0    Train name  Train no     City  Unnamed: 4  Unnamed: 5  \
# 0           0      shatabdi    103044  lucknow         NaN         NaN
# 1           1      rajdhani    134345   mumbai         NaN         NaN
# 2           2  Vande bharat    553567  varansi         NaN         NaN
# 3           3         Tejas    535646    delhi         NaN         NaN
#
#    Unnamed: 6
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN

# %%
train
# Out:
#    Unnamed: 0    Train name  Train no     City  Unnamed: 4  Unnamed: 5  \
# 0           0      shatabdi    103044  lucknow         NaN         NaN
# 1           1      rajdhani    134345   mumbai         NaN         NaN
# 2           2  Vande bharat    553567  varansi         NaN         NaN
# 3           3         Tejas    535646    delhi         NaN         NaN
#
#    Unnamed: 6
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN

# %%
train['Train name']
# Out:
# 0        shatabdi
# 1        rajdhani
# 2    Vande bharat
# 3           Tejas
# Name: Train name, dtype: object

# %%
train['Train number'][0]=876546
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/pandas/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Train number'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 train['Train number'][0]=876546
#
# ...

# %%
train
# Out:
#    Unnamed: 0    Train name  Train no     City  Unnamed: 4  Unnamed: 5  \
# 0           0      shatabdi    103044  lucknow         NaN         NaN
# 1           1      rajdhani    134345   mumbai         NaN         NaN
# 2           2  Vande bharat    553567  varansi         NaN         NaN
# 3           3         Tejas    535646    delhi         NaN         NaN
#
#    Unnamed: 6
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN

# %%
train.index=['I','II','III','IV']

# %%
train.to_csv("Train.csv")

# %%
train
# Out:
#      Unnamed: 0    Train name  Train no     City  Unnamed: 4  Unnamed: 5  \
# I             0      shatabdi    103044  lucknow         NaN         NaN
# II            1      rajdhani    134345   mumbai         NaN         NaN
# III           2  Vande bharat    553567  varansi         NaN         NaN
# IV            3         Tejas    535646    delhi         NaN         NaN
#
#      Unnamed: 6
# I           NaN
# II          NaN
# III         NaN
# IV          NaN

# %%
train.drop("Unnamed: 4",axis=1)
# Out:
#      Unnamed: 0    Train name  Train no     City  Unnamed: 5  Unnamed: 6
# I             0      shatabdi    103044  lucknow         NaN         NaN
# II            1      rajdhani    134345   mumbai         NaN         NaN
# III           2  Vande bharat    553567  varansi         NaN         NaN
# IV            3         Tejas    535646    delhi         NaN         NaN

# %%
train.drop("Unnamed: 0",axis=1)
# Out:
#        Train name  Train no     City  Unnamed: 4  Unnamed: 5  Unnamed: 6
# I        shatabdi    103044  lucknow         NaN         NaN         NaN
# II       rajdhani    134345   mumbai         NaN         NaN         NaN
# III  Vande bharat    553567  varansi         NaN         NaN         NaN
# IV          Tejas    535646    delhi         NaN         NaN         NaN

# %%
train.drop("Unnamed: 4",axis=1)
# Out:
#      Unnamed: 0    Train name  Train no     City  Unnamed: 5  Unnamed: 6
# I             0      shatabdi    103044  lucknow         NaN         NaN
# II            1      rajdhani    134345   mumbai         NaN         NaN
# III           2  Vande bharat    553567  varansi         NaN         NaN
# IV            3         Tejas    535646    delhi         NaN         NaN

# %%
train.drop("Unnamed: 5",axis=1)
# Out:
#      Unnamed: 0    Train name  Train no     City  Unnamed: 4  Unnamed: 6
# I             0      shatabdi    103044  lucknow         NaN         NaN
# II            1      rajdhani    134345   mumbai         NaN         NaN
# III           2  Vande bharat    553567  varansi         NaN         NaN
# IV            3         Tejas    535646    delhi         NaN         NaN

# %%
train.drop("Unnamed: 6",axis=1)
# Out:
#      Unnamed: 0    Train name  Train no     City  Unnamed: 4  Unnamed: 5
# I             0      shatabdi    103044  lucknow         NaN         NaN
# II            1      rajdhani    134345   mumbai         NaN         NaN
# III           2  Vande bharat    553567  varansi         NaN         NaN
# IV            3         Tejas    535646    delhi         NaN         NaN

# %%
train.dropna()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Train name, Train no, City, Unnamed: 4, Unnamed: 5, Unnamed: 6]
# Index: []

# %%
train
# Out:
#      Unnamed: 0    Train name  Train no     City  Unnamed: 4  Unnamed: 5  \
# I             0      shatabdi    103044  lucknow         NaN         NaN
# II            1      rajdhani    134345   mumbai         NaN         NaN
# III           2  Vande bharat    553567  varansi         NaN         NaN
# IV            3         Tejas    535646    delhi         NaN         NaN
#
#      Unnamed: 6
# I           NaN
# II          NaN
# III         NaN
# IV          NaN
